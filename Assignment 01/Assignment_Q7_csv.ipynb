# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
data = pd.read_csv("Q7.csv")

# %%
data.head(5)
# Out:
#           Unnamed: 0  Points  Score  Weigh
# 0          Mazda RX4    3.90  2.620  16.46
# 1      Mazda RX4 Wag    3.90  2.875  17.02
# 2         Datsun 710    3.85  2.320  18.61
# 3     Hornet 4 Drive    3.08  3.215  19.44
# 4  Hornet Sportabout    3.15  3.440  17.02

# %%
mean = np.mean(data)
print(mean)

# %%
median = np.median(data)
print(median) #Sorry,Tried using StackOverflow and still not working.

# %%
mode = stats.mode(data).mode[0]
print(mode) #Sorry,Tried using StackOverflow and still not working.

# %%
variance = np.var(data)
print(variance)

# %%
std_deviation = np.std(data)
print(std_deviation)

# %%
data_range = np.ptp(data)
print(data_range)  #Sorry,Tried using StackOverflow and still not working.
